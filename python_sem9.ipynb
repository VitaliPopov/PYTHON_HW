# %% [markdown]
# <a href="https://colab.research.google.com/github/VitaliPopov/PYTHON_HW/blob/main/python_sem9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
datafr = pd.read_csv('sample_data/california_housing_test.csv', sep = ",", encoding = "utf-8")
datafr.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0
# 5       663.0       204.0         1.6635             67000.0
# 6       604.0       218.0         1.6641             67000.0
# 7      1341.0       441.0         3.2250            166900.0
# 8      1446.0       599.0         3.6696            194400.0
# 9      2830.0       603.0         2.3333            164200.0

# %%
datafr.shape
# Out:
# (3000, 9)

# %%
datafr.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
datafr.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
# Задача №59. Решение в группах
# 1. Проверить есть ли в файле пустые значения
# 2. Показать median_house_value где median_income < 2
# 3. Показать данные в первых 2 столбцах
# 4. Выбрать данные где housing_median_age < 20 и
# median_house_value > 70000
datafr.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
datafr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
datafr[datafr['median_income']<2]['median_house_value']
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
for item in datafr.columns[:2]:
  print(datafr[item])
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64
# 0       37.37
# 1       34.26
# 2       33.78
# 3       33.82
# 4       36.33
#         ...
# 2995    34.42
# 2996    34.06
# 2997    36.30
# 2998    34.10
# 2999    34.42
# Name: latitude, Length: 3000, dtype: float64

# %%
datafr[(datafr['housing_median_age']<20)&(datafr['median_house_value']<70000)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
#
# 2688       370.0       177.0         1.3000             69700.0
# 2740       772.0       220.0         2.1771             39200.0
# 2779      4781.0      1919.0         1.7109             44600.0
# 2902      1614.0       731.0         1.6236             67300.0
# 2997       693.0       220.0         2.2895             62000.0

# %%
'''Задача №61. Решение в группах
1. Определить какое максимальное и минимальное
значение median_house_value
2. Показать максимальное median_house_value, где
median_income = 3.1250
3. Узнать какая максимальная population в зоне
минимального значения median_house_value
'''
print('Max =', datafr['median_house_value'].max(), 'Min =', datafr['median_house_value'].min())
# Out:
# Max = 500001.0 Min = 22500.0

# %%
datafr[(datafr['median_income'] == 3.1250)][['median_house_value']]
# Out:
#       median_house_value
# 207             167100.0
# 784             233300.0
# 904             156300.0
# 1908            219900.0

# %%
datafr[(datafr['median_income'] == 3.1250) & (datafr['median_house_value'].max()), 'median_house_value']

# %%
datafr[(datafr['median_house_value'] == datafr['median_house_value'].min())]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2001    -117.16     32.71                52.0        845.0           451.0
#
#       population  households  median_income  median_house_value
# 2001      1230.0       375.0         1.0918             22500.0

# %%
datafr['total_result']=0

# %%
datafr
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value total_result  \
# 0         1537.0       606.0         6.6085            344700.0         rich
# 1          809.0       277.0         3.5990            176500.0       middle
# 2         1484.0       495.0         5.7934            270500.0         rich
# 3           49.0        11.0         6.1359            330000.0         rich
# 4          850.0       237.0         2.9375             81700.0       middle
# ...          ...         ...            ...                 ...          ...
# 2995      1258.0       607.0         1.1790            225000.0         poor
# 2996      3496.0      1036.0         3.3906            237200.0       middle
# 2997       693.0       220.0         2.2895             62000.0       middle
# 2998        46.0        14.0         3.2708            162500.0       middle
# 2999       753.0       260.0         8.5608            500001.0         rich
#
#       total_new  total_new1
# 0       60600.0           2
# 1       27700.0           1
# 2       49500.0           1
# 3        1100.0           0
# 4       23700.0           1
# ...         ...         ...
# 2995    60700.0           2
# 2996   103600.0           2
# 2997    22000.0           1
# 2998     1400.0           0
# 2999    26000.0           1
#
# [3000 rows x 12 columns]

# %%
datafr['total_new']= datafr['households'].apply (lambda x: x*100)

# %%
datafr.loc [(datafr['median_income']>5), 'total_result'] = 'rich'
datafr.loc [(datafr['median_income']>=2)&(datafr['median_income']<=5), 'total_result'] = 'middle'
datafr.loc [(datafr['median_income']<2), 'total_result'] = 'poor'

# %%
def func (x):
  if x<200:
    res = 0
  elif 200<= x <500:
    res = 1
  else:
    res = 2
  return res
datafr['total_new1']= datafr['households'].apply (func)

# %%
'''Задача 40: Работать с файлом california_housing_train.csv, который находится в папке
sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population)
'''
datafr[(datafr['median_house_value'].mean()) & (0<=datafr['population']<=500), 'median_house_value']

# %%
'''
Задача 42: Узнать какая максимальная households в зоне минимального значения population
'''
datafr[(datafr['households'].max()) & (datafr['population'].min()), 'households']
