# %% [markdown]
# <a href="https://colab.research.google.com/github/VitaliPopov/PYTHON_HW/blob/main/python_sem9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
datafr = pd.read_csv('sample_data/california_housing_test.csv', sep = ",", encoding = "utf-8")
datafr.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
datafr.shape
# Out:
# (3000, 9)

# %%
datafr.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
datafr.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
# Задача №59. Решение в группах
# 1. Проверить есть ли в файле пустые значения
# 2. Показать median_house_value где median_income < 2
# 3. Показать данные в первых 2 столбцах
# 4. Выбрать данные где housing_median_age < 20 и
# median_house_value > 70000
datafr.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
datafr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
datafr[datafr['median_income']<2]['median_house_value']
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
for item in datafr.columns[:2]:
  print(datafr[item])
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64
# 0       37.37
# 1       34.26
# 2       33.78
# 3       33.82
# 4       36.33
#         ...
# 2995    34.42
# 2996    34.06
# 2997    36.30
# 2998    34.10
# 2999    34.42
# Name: latitude, Length: 3000, dtype: float64

# %%
datafr[(datafr['housing_median_age']<20)&(datafr['median_house_value']<70000)]

# %%
'''Задача №61. Решение в группах
1. Определить какое максимальное и минимальное
значение median_house_value
2. Показать максимальное median_house_value, где
median_income = 3.1250
3. Узнать какая максимальная population в зоне
минимального значения median_house_value
'''
print('Max =', datafr['median_house_value'].max(), 'Min =', datafr['median_house_value'].min())
# Out:
# Max = 500001.0 Min = 22500.0

# %%
datafr[(datafr['median_income'] == 3.1250)][['median_house_value']]
# Out:
#       median_house_value
# 207             167100.0
# 784             233300.0
# 904             156300.0
# 1908            219900.0

# %%
datafr [datafr.median_income == 3.1250]['median_house_value'].max(), 'median_house_value'
# Out:
# (233300.0, 'median_house_value')

# %%
datafr[(datafr['median_house_value'] == datafr['median_house_value'].min())]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2001    -117.16     32.71                52.0        845.0           451.0
#
#       population  households  median_income  median_house_value
# 2001      1230.0       375.0         1.0918             22500.0

# %%
datafr['total_result']=0

# %%
datafr

# %%
datafr['total_new']= datafr['households'].apply (lambda x: x*100)

# %%
datafr.loc [(datafr['median_income']>5), 'total_result'] = 'rich'
datafr.loc [(datafr['median_income']>=2)&(datafr['median_income']<=5), 'total_result'] = 'middle'
datafr.loc [(datafr['median_income']<2), 'total_result'] = 'poor'

# %%
def func (x):
  if x<200:
    res = 0
  elif 200<= x <500:
    res = 1
  else:
    res = 2
  return res
datafr['total_new1']= datafr['households'].apply (func)

# %%
'''Задача 40: Работать с файлом california_housing_train.csv, который находится в папке
sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population)
'''
import pandas as pd
df = pd.read_csv('sample_data/california_housing_train.csv', sep = ",", encoding = "utf-8")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df[(0<=df['population']) & (df['population']<500)].median_house_value.mean(), 'median_house_value'
# Out:
# (206683.83635227982, 'median_house_value')

# %%
'''
Задача 42: Узнать какая максимальная households в зоне минимального значения population
'''
df[df['population'] == df['population'].min()].households.max(), 'households'
# Out:
# (4.0, 'households')

# %%
'''
Изобразите отношение households к population с помощью точечного графика

Визуализировать longitude по отношения к median_house_value, используя линейный график
Представить гистограмму по housing_median_age
Изобразить гистограмму по median_house_value с оттенком housing_median_age
'''
import seaborn as sns
sns.scatterplot(data= datafr, x = 'population', y = 'households')
# Out:
# <Axes: xlabel='population', ylabel='households'>

# %%
sns.relplot(data= datafr, x ='longitude', y= 'median_house_value', kind = 'line')

# %%
sns.histplot(data= datafr, x= 'housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
sns.histplot(data= datafr, x= 'median_house_value', hue = 'housing_median_age')
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %%
sns.displot(data= datafr, x= 'median_house_value', hue = 'housing_median_age')

# %%
'''
Задача №65. Решение в группах
Написать EDA для датасета про пингвинов
Необходимо:
● Использовать 2-3 точечных графика
● Применить доп измерение в точечных графиках, используя
аргументы hue, size, stile
● Использовать PairGrid с типом графика на ваш выбор
● Изобразить Heatmap
● Использовать 2-3 гистограммы
Чтобы подключить датасет с
пингвинами, воспользуйтесь данным
скриптом:
penguins = sns.load_dataset("penguins")
penguins.head()
'''
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.scatterplot(data= penguins, x = 'flipper_length_mm', y = 'body_mass_g', hue ='sex')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
cols = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
g = sns.PairGrid(penguins[cols])
g.map(sns.scatterplot)
